# %% [markdown]
# <a href="https://colab.research.google.com/github/EinarLop/adaptive_reliability_evaluation_system_GCNN/blob/main/2M_3S_E1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install torch_geometric (everything else is pre-installed in Colab
# Add more rows if woring from Pycharm etc.)
! pip install torch_geometric
#Unzip the archive with data
#!unzip results.zip
# Out:
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2024.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.12.2)

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
# Red all matrix files and convert them into a list of lists
mat_files = sorted(glob.glob('/content/*.mat'))
if '/content/config_1.mat' in mat_files:
    mat_files.remove('/content/config_1.mat')

all_matrices = []
for path in mat_files:
  with open(path, 'r') as f:
    content = f.read()
  # Remove the first and last character ('[' and ']')
  content = content[1:-1]
  string_list = []
  current_row = ''
  start_line = False
  for c in content:
      if c == '[':
          start_line = True
      elif c == ']':
          start_line = False
          string_list.append(current_row)
          current_row = ''
      elif start_line:
          if c != '\n':
              current_row += c
  matrix = []
  for string in string_list:
    vals = string.replace('.', ' ').split()
    vals = [int(v) for v in vals]
    matrix.append(vals)
  all_matrices.append(matrix)

# %%
# Convert adjacency matrices into edge indices.
# An edge index is a 2 x Num_Of_Vert array. Here is an example
# [[ 1, 2, 2, 3],
#  [ 2, 1, 3, 2]]
# You read the list by pairing numbers from top row with numbers from bottom row
# In this example, 1 connects to 2, 2 connects to 1, 2 connects to 3,
# and 3 connects to 2.
# PyTorch Geometric works with this format of edge connection

# List to hold edge indices for all indices
all_edge_indices = []

# Process each matrix in the list
for matrix in all_matrices:
    # Convert the 2D list to a numpy array
    matrix_np = np.array(matrix)

    # Get the indices where there are edges (i.e., non-zero entries)
    edge_indices = np.nonzero(matrix_np)

    # Stack the indices into a 2xN array where each column represents an edge
    edge_index = torch.tensor(np.vstack(edge_indices), dtype=torch.long)

    # Append the edge_index tensor to the list
    all_edge_indices.append(edge_index)

# %%
rel_files = sorted(glob.glob('/content/*.rel'))
all_rels = []

if '/content/config_1.rel' in rel_files:
    rel_files.remove('/content/config_1.rel')

for path in rel_files:
    with open(path, 'r') as f:
        y_val = float(f.read())
    all_rels.append(y_val)

# %%
plt.figure(figsize=(8, 6))
plt.hist(all_rels, bins=20, edgecolor='k', alpha=0.7)  # Adjust bins as needed
plt.title("Distribution of y Values")
plt.xlabel("y")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(all_rels, vert=False, patch_artist=True)
plt.title("Box Plot of y Values")
plt.xlabel("y")
plt.show()

# %%
# Convert the list of float values to a PyTorch tensor
all_rels_tensor = torch.tensor(all_rels)

# %% [markdown]
# # Scaling

# %% [markdown]
# Amplification k=5 :
# - Mean Squared Error on Test Set: 3.4444
# - R^2 Score on Test Set: -0.0326
#
# Normalization:
# - Mean Squared Error on Test Set: 0.1335
# - R^2 Score on Test Set: -0.0004
#
# Standarization:
# - Mean Squared Error on Test Set: 1.0188
# - R^2 Score on Test Set: -0.0003

# %%
technique = 3

# Amplification
if technique == 0:
  y_min = all_rels_tensor.min()
  y_max = all_rels_tensor.max()
  K = 100
  all_rels_tensor = (all_rels_tensor - y_min) / (y_max - y_min) * K

# Normalization
elif technique == 1:
  y_min = all_rels_tensor.min()
  y_max = all_rels_tensor.max()
  all_rels_tensor = (all_rels_tensor - y_min) / (y_max - y_min)
  print(f'min: {y_min}, max: {y_max}')

# Standarization
elif technique == 2:
  y_mean = all_rels_tensor.mean()
  y_std = all_rels_tensor.std()
  all_rels_tensor = (all_rels_tensor - y_mean) / y_std

# No modificstion
elif technique == 3:
  print(f'min: {y_min}, max: {y_max}')

  pass
# Out:
# min: 0.9704145193099976, max: 0.9985337853431702

# %%
#Create one Data object per graph and put them into one list
# TODO: Create PyTOrch Geometric Dataset object (https://pytorch-geometric.readthedocs.io/en/latest/tutorial/create_dataset.html)
# Each Data object should have node features in a tensor called X,
# (we dont' have any node features yet, that's why there are placeholders)
# target tensor called Y, and edge_index from before.
data_list = []
for i in range(len(all_matrices)):
  num_nodes = len(all_matrices[i])  # Number of nodes from adjacency matrix
  node_features = torch.ones((num_nodes, 1))  # Dummy feature of 1.0 for each node
  edge_index = all_edge_indices[i]
  #TODO: there is one less rel file than mat files. It is because config1 (empty config)
  #Does not have corresponding rel value (which makes sense because empty system doesnt have reliability)
  #Because of that there is one less y valye than x values. I think the easest way to fix this
  #is by removing config1.mat entirely, but I am irested in your thoughts - Pasha
  y = all_rels_tensor[i]

  data = Data(x=node_features, edge_index=edge_index, y=y)
  data_list.append(data)

# %%
from sklearn.model_selection import train_test_split

# Split data and create DataLoader objects for training
train_data_list, test_data_list = train_test_split(data_list, test_size=0.2, random_state=42)


train_loader = DataLoader(train_data_list, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data_list, batch_size=32, shuffle=False)

# %%
# Define a GCN (this one is from PyTorch Geometric tutorial, feel free to experiment)
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool

class GCN(torch.nn.Module):
    def __init__(self, num_node_features = 1):
        super().__init__()
        self.conv1 = GCNConv(num_node_features, 32)
        self.conv2 = GCNConv(32, 16)
        self.fc = torch.nn.Linear(16, 1)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)

        # Second GCN layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)

        # Global mean pooling to get graph-level representation
        x = global_mean_pool(x, batch)  # Shape: [batch_size, hidden_channels]

        # Final fully connected layer
        x = torch.sigmoid(self.fc(x))


        return x

# %%
import torch.optim as optim
import time
import os

# Initialize the model, optimizer, and loss function
model = GCN()  # Since our node features have dimension 1
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

# Training parameters
num_epochs = 2000
patience = 100  # Early stopping patience
min_val_loss = float('inf')  # To track the minimum validation loss
patience_counter = 0  # To count epochs without improvement
checkpoint_path = "best_model.pth"  # File path for the checkpoint

# Training loop
for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for data in train_loader:
        optimizer.zero_grad()
        out = model(data).squeeze()  # Shape: [batch_size]
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs  # Accumulate loss

    avg_train_loss = total_loss / len(data_list)

    # Validation Phase
    model.eval()
    total_val_loss = 0

    # Prediction time
    total_predictions = 0
    total_prediction_time = 0

    with torch.no_grad():
        for data in test_loader:
            # Start time
            batch_start_time = time.time()

            out = model(data).squeeze()

            # End time
            batch_end_time = time.time()
            batch_prediction_time = batch_end_time - batch_start_time
            total_prediction_time += batch_prediction_time

            total_predictions += data.num_graphs

            loss = criterion(out, data.y)
            total_val_loss += loss.item() * data.num_graphs

    avg_val_loss = total_val_loss / len(test_data_list)
    avg_prediction_time = total_prediction_time / total_predictions

    print(f"Epoch {epoch + 1}/{num_epochs}, Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Average Prediction Time (s): {avg_prediction_time:.6f} per graph\n")

    # Check for improvement in validation loss
    if avg_val_loss < min_val_loss:
        min_val_loss = avg_val_loss
        patience_counter = 0  # Reset patience counter

        # Save the best model checkpoint
        torch.save(model.state_dict(), checkpoint_path)
    else:
        patience_counter += 1
        print(f"No improvement in validation loss for {patience_counter} epoch(s).\n")

    # Check if patience has been exceeded
    if patience_counter >= patience:
        print(f"Early stopping triggered after {patience} epochs without improvement.")
        break

# Load the best model checkpoint (optional, after training is complete)
if os.path.exists(checkpoint_path):
    model.load_state_dict(torch.load(checkpoint_path))
    print("Loaded the best model from checkpoint.")
# Out:
# Epoch 1/2000, Training Loss: 0.1656, Validation Loss: 0.1830, Average Prediction Time (s): 0.000093 per graph
#
# Epoch 2/2000, Training Loss: 0.1431, Validation Loss: 0.1585, Average Prediction Time (s): 0.000087 per graph
#
# Epoch 3/2000, Training Loss: 0.1186, Validation Loss: 0.1350, Average Prediction Time (s): 0.000094 per graph
#
# Epoch 4/2000, Training Loss: 0.1042, Validation Loss: 0.1388, Average Prediction Time (s): 0.000074 per graph
#
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 5/2000, Training Loss: 0.1068, Validation Loss: 0.1407, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 2 epoch(s).
#
# Epoch 6/2000, Training Loss: 0.1058, Validation Loss: 0.1351, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 3 epoch(s).
#
# Epoch 7/2000, Training Loss: 0.1037, Validation Loss: 0.1334, Average Prediction Time (s): 0.000069 per graph
#
# Epoch 8/2000, Training Loss: 0.1043, Validation Loss: 0.1335, Average Prediction Time (s): 0.000077 per graph
#
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 9/2000, Training Loss: 0.1041, Validation Loss: 0.1334, Average Prediction Time (s): 0.000072 per graph
#
# Epoch 10/2000, Training Loss: 0.1043, Validation Loss: 0.1345, Average Prediction Time (s): 0.000071 per graph
#
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 11/2000, Training Loss: 0.1038, Validation Loss: 0.1344, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 2 epoch(s).
#
# Epoch 12/2000, Training Loss: 0.1038, Validation Loss: 0.1336, Average Prediction Time (s): 0.000071 per graph
#
# No improvement in validation loss for 3 epoch(s).
#
# Epoch 13/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000074 per graph
#
# No improvement in validation loss for 4 epoch(s).
#
# Epoch 14/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000067 per graph
#
# No improvement in validation loss for 5 epoch(s).
#
# Epoch 15/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 6 epoch(s).
#
# Epoch 16/2000, Training Loss: 0.1037, Validation Loss: 0.1337, Average Prediction Time (s): 0.000124 per graph
#
# No improvement in validation loss for 7 epoch(s).
#
# Epoch 17/2000, Training Loss: 0.1038, Validation Loss: 0.1343, Average Prediction Time (s): 0.000111 per graph
#
# No improvement in validation loss for 8 epoch(s).
#
# Epoch 18/2000, Training Loss: 0.1037, Validation Loss: 0.1340, Average Prediction Time (s): 0.000127 per graph
#
# No improvement in validation loss for 9 epoch(s).
#
# Epoch 19/2000, Training Loss: 0.1037, Validation Loss: 0.1334, Average Prediction Time (s): 0.000371 per graph
#
# Epoch 20/2000, Training Loss: 0.1038, Validation Loss: 0.1336, Average Prediction Time (s): 0.000149 per graph
#
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 21/2000, Training Loss: 0.1037, Validation Loss: 0.1339, Average Prediction Time (s): 0.000123 per graph
#
# No improvement in validation loss for 2 epoch(s).
#
# Epoch 22/2000, Training Loss: 0.1036, Validation Loss: 0.1341, Average Prediction Time (s): 0.000284 per graph
#
# No improvement in validation loss for 3 epoch(s).
#
# Epoch 23/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000103 per graph
#
# No improvement in validation loss for 4 epoch(s).
#
# Epoch 24/2000, Training Loss: 0.1051, Validation Loss: 0.1335, Average Prediction Time (s): 0.000100 per graph
#
# No improvement in validation loss for 5 epoch(s).
#
# Epoch 25/2000, Training Loss: 0.1040, Validation Loss: 0.1336, Average Prediction Time (s): 0.000162 per graph
#
# No improvement in validation loss for 6 epoch(s).
#
# Epoch 26/2000, Training Loss: 0.1033, Validation Loss: 0.1344, Average Prediction Time (s): 0.000108 per graph
#
# No improvement in validation loss for 7 epoch(s).
#
# Epoch 27/2000, Training Loss: 0.1041, Validation Loss: 0.1360, Average Prediction Time (s): 0.000115 per graph
#
# No improvement in validation loss for 8 epoch(s).
#
# Epoch 28/2000, Training Loss: 0.1042, Validation Loss: 0.1346, Average Prediction Time (s): 0.000333 per graph
#
# No improvement in validation loss for 9 epoch(s).
#
# Epoch 29/2000, Training Loss: 0.1034, Validation Loss: 0.1335, Average Prediction Time (s): 0.000152 per graph
#
# No improvement in validation loss for 10 epoch(s).
#
# Epoch 30/2000, Training Loss: 0.1036, Validation Loss: 0.1334, Average Prediction Time (s): 0.000112 per graph
#
# Epoch 31/2000, Training Loss: 0.1039, Validation Loss: 0.1334, Average Prediction Time (s): 0.000111 per graph
#
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 32/2000, Training Loss: 0.1038, Validation Loss: 0.1340, Average Prediction Time (s): 0.000107 per graph
#
# No improvement in validation loss for 2 epoch(s).
#
# Epoch 33/2000, Training Loss: 0.1040, Validation Loss: 0.1345, Average Prediction Time (s): 0.000141 per graph
#
# No improvement in validation loss for 3 epoch(s).
#
# Epoch 34/2000, Training Loss: 0.1037, Validation Loss: 0.1340, Average Prediction Time (s): 0.000244 per graph
#
# No improvement in validation loss for 4 epoch(s).
#
# Epoch 35/2000, Training Loss: 0.1040, Validation Loss: 0.1334, Average Prediction Time (s): 0.000112 per graph
#
# No improvement in validation loss for 5 epoch(s).
#
# Epoch 36/2000, Training Loss: 0.1036, Validation Loss: 0.1336, Average Prediction Time (s): 0.000106 per graph
#
# No improvement in validation loss for 6 epoch(s).
#
# Epoch 37/2000, Training Loss: 0.1057, Validation Loss: 0.1356, Average Prediction Time (s): 0.000131 per graph
#
# No improvement in validation loss for 7 epoch(s).
#
# Epoch 38/2000, Training Loss: 0.1042, Validation Loss: 0.1342, Average Prediction Time (s): 0.000130 per graph
#
# No improvement in validation loss for 8 epoch(s).
#
# Epoch 39/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000276 per graph
#
# No improvement in validation loss for 9 epoch(s).
#
# Epoch 40/2000, Training Loss: 0.1035, Validation Loss: 0.1335, Average Prediction Time (s): 0.000112 per graph
#
# No improvement in validation loss for 10 epoch(s).
#
# Epoch 41/2000, Training Loss: 0.1040, Validation Loss: 0.1334, Average Prediction Time (s): 0.000117 per graph
#
# No improvement in validation loss for 11 epoch(s).
#
# Epoch 42/2000, Training Loss: 0.1037, Validation Loss: 0.1344, Average Prediction Time (s): 0.000153 per graph
#
# No improvement in validation loss for 12 epoch(s).
#
# Epoch 43/2000, Training Loss: 0.1041, Validation Loss: 0.1351, Average Prediction Time (s): 0.000123 per graph
#
# No improvement in validation loss for 13 epoch(s).
#
# Epoch 44/2000, Training Loss: 0.1038, Validation Loss: 0.1340, Average Prediction Time (s): 0.000113 per graph
#
# No improvement in validation loss for 14 epoch(s).
#
# Epoch 45/2000, Training Loss: 0.1044, Validation Loss: 0.1334, Average Prediction Time (s): 0.000116 per graph
#
# No improvement in validation loss for 15 epoch(s).
#
# Epoch 46/2000, Training Loss: 0.1040, Validation Loss: 0.1336, Average Prediction Time (s): 0.000108 per graph
#
# No improvement in validation loss for 16 epoch(s).
#
# Epoch 47/2000, Training Loss: 0.1036, Validation Loss: 0.1336, Average Prediction Time (s): 0.000114 per graph
#
# No improvement in validation loss for 17 epoch(s).
#
# Epoch 48/2000, Training Loss: 0.1036, Validation Loss: 0.1335, Average Prediction Time (s): 0.000119 per graph
#
# No improvement in validation loss for 18 epoch(s).
#
# Epoch 49/2000, Training Loss: 0.1038, Validation Loss: 0.1340, Average Prediction Time (s): 0.000276 per graph
#
# No improvement in validation loss for 19 epoch(s).
#
# Epoch 50/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000106 per graph
#
# No improvement in validation loss for 20 epoch(s).
#
# Epoch 51/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000113 per graph
#
# No improvement in validation loss for 21 epoch(s).
#
# Epoch 52/2000, Training Loss: 0.1039, Validation Loss: 0.1335, Average Prediction Time (s): 0.000074 per graph
#
# No improvement in validation loss for 22 epoch(s).
#
# Epoch 53/2000, Training Loss: 0.1036, Validation Loss: 0.1344, Average Prediction Time (s): 0.000072 per graph
#
# No improvement in validation loss for 23 epoch(s).
#
# Epoch 54/2000, Training Loss: 0.1037, Validation Loss: 0.1342, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 24 epoch(s).
#
# Epoch 55/2000, Training Loss: 0.1047, Validation Loss: 0.1334, Average Prediction Time (s): 0.000076 per graph
#
# No improvement in validation loss for 25 epoch(s).
#
# Epoch 56/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000075 per graph
#
# No improvement in validation loss for 26 epoch(s).
#
# Epoch 57/2000, Training Loss: 0.1043, Validation Loss: 0.1345, Average Prediction Time (s): 0.000068 per graph
#
# No improvement in validation loss for 27 epoch(s).
#
# Epoch 58/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000082 per graph
#
# No improvement in validation loss for 28 epoch(s).
#
# Epoch 59/2000, Training Loss: 0.1042, Validation Loss: 0.1334, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 29 epoch(s).
#
# Epoch 60/2000, Training Loss: 0.1039, Validation Loss: 0.1335, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 30 epoch(s).
#
# Epoch 61/2000, Training Loss: 0.1037, Validation Loss: 0.1341, Average Prediction Time (s): 0.000081 per graph
#
# No improvement in validation loss for 31 epoch(s).
#
# Epoch 62/2000, Training Loss: 0.1037, Validation Loss: 0.1342, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 32 epoch(s).
#
# Epoch 63/2000, Training Loss: 0.1036, Validation Loss: 0.1336, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 33 epoch(s).
#
# Epoch 64/2000, Training Loss: 0.1039, Validation Loss: 0.1334, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 34 epoch(s).
#
# Epoch 65/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000079 per graph
#
# No improvement in validation loss for 35 epoch(s).
#
# Epoch 66/2000, Training Loss: 0.1035, Validation Loss: 0.1345, Average Prediction Time (s): 0.000073 per graph
#
# No improvement in validation loss for 36 epoch(s).
#
# Epoch 67/2000, Training Loss: 0.1045, Validation Loss: 0.1351, Average Prediction Time (s): 0.000071 per graph
#
# No improvement in validation loss for 37 epoch(s).
#
# Epoch 68/2000, Training Loss: 0.1040, Validation Loss: 0.1334, Average Prediction Time (s): 0.000079 per graph
#
# No improvement in validation loss for 38 epoch(s).
#
# Epoch 69/2000, Training Loss: 0.1039, Validation Loss: 0.1334, Average Prediction Time (s): 0.000075 per graph
#
# Epoch 70/2000, Training Loss: 0.1038, Validation Loss: 0.1336, Average Prediction Time (s): 0.000068 per graph
#
# No improvement in validation loss for 1 epoch(s).
#
# Epoch 71/2000, Training Loss: 0.1035, Validation Loss: 0.1340, Average Prediction Time (s): 0.000073 per graph
#
# No improvement in validation loss for 2 epoch(s).
#
# Epoch 72/2000, Training Loss: 0.1037, Validation Loss: 0.1345, Average Prediction Time (s): 0.000079 per graph
#
# No improvement in validation loss for 3 epoch(s).
#
# Epoch 73/2000, Training Loss: 0.1040, Validation Loss: 0.1345, Average Prediction Time (s): 0.000135 per graph
#
# No improvement in validation loss for 4 epoch(s).
#
# Epoch 74/2000, Training Loss: 0.1039, Validation Loss: 0.1335, Average Prediction Time (s): 0.000657 per graph
#
# No improvement in validation loss for 5 epoch(s).
#
# Epoch 75/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000101 per graph
#
# No improvement in validation loss for 6 epoch(s).
#
# Epoch 76/2000, Training Loss: 0.1037, Validation Loss: 0.1338, Average Prediction Time (s): 0.000096 per graph
#
# No improvement in validation loss for 7 epoch(s).
#
# Epoch 77/2000, Training Loss: 0.1038, Validation Loss: 0.1338, Average Prediction Time (s): 0.000074 per graph
#
# No improvement in validation loss for 8 epoch(s).
#
# Epoch 78/2000, Training Loss: 0.1036, Validation Loss: 0.1339, Average Prediction Time (s): 0.000094 per graph
#
# No improvement in validation loss for 9 epoch(s).
#
# Epoch 79/2000, Training Loss: 0.1037, Validation Loss: 0.1341, Average Prediction Time (s): 0.000094 per graph
#
# No improvement in validation loss for 10 epoch(s).
#
# Epoch 80/2000, Training Loss: 0.1041, Validation Loss: 0.1345, Average Prediction Time (s): 0.000101 per graph
#
# No improvement in validation loss for 11 epoch(s).
#
# Epoch 81/2000, Training Loss: 0.1041, Validation Loss: 0.1335, Average Prediction Time (s): 0.000167 per graph
#
# No improvement in validation loss for 12 epoch(s).
#
# Epoch 82/2000, Training Loss: 0.1037, Validation Loss: 0.1339, Average Prediction Time (s): 0.000096 per graph
#
# No improvement in validation loss for 13 epoch(s).
#
# Epoch 83/2000, Training Loss: 0.1036, Validation Loss: 0.1340, Average Prediction Time (s): 0.000094 per graph
#
# No improvement in validation loss for 14 epoch(s).
#
# Epoch 84/2000, Training Loss: 0.1045, Validation Loss: 0.1347, Average Prediction Time (s): 0.000094 per graph
#
# No improvement in validation loss for 15 epoch(s).
#
# Epoch 85/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000097 per graph
#
# No improvement in validation loss for 16 epoch(s).
#
# Epoch 86/2000, Training Loss: 0.1037, Validation Loss: 0.1334, Average Prediction Time (s): 0.000100 per graph
#
# No improvement in validation loss for 17 epoch(s).
#
# Epoch 87/2000, Training Loss: 0.1039, Validation Loss: 0.1334, Average Prediction Time (s): 0.000090 per graph
#
# No improvement in validation loss for 18 epoch(s).
#
# Epoch 88/2000, Training Loss: 0.1043, Validation Loss: 0.1337, Average Prediction Time (s): 0.000092 per graph
#
# No improvement in validation loss for 19 epoch(s).
#
# Epoch 89/2000, Training Loss: 0.1035, Validation Loss: 0.1335, Average Prediction Time (s): 0.000093 per graph
#
# No improvement in validation loss for 20 epoch(s).
#
# Epoch 90/2000, Training Loss: 0.1040, Validation Loss: 0.1336, Average Prediction Time (s): 0.000099 per graph
#
# No improvement in validation loss for 21 epoch(s).
#
# Epoch 91/2000, Training Loss: 0.1040, Validation Loss: 0.1334, Average Prediction Time (s): 0.000087 per graph
#
# No improvement in validation loss for 22 epoch(s).
#
# Epoch 92/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000092 per graph
#
# No improvement in validation loss for 23 epoch(s).
#
# Epoch 93/2000, Training Loss: 0.1036, Validation Loss: 0.1339, Average Prediction Time (s): 0.000090 per graph
#
# No improvement in validation loss for 24 epoch(s).
#
# Epoch 94/2000, Training Loss: 0.1037, Validation Loss: 0.1341, Average Prediction Time (s): 0.000096 per graph
#
# No improvement in validation loss for 25 epoch(s).
#
# Epoch 95/2000, Training Loss: 0.1037, Validation Loss: 0.1340, Average Prediction Time (s): 0.000088 per graph
#
# No improvement in validation loss for 26 epoch(s).
#
# Epoch 96/2000, Training Loss: 0.1038, Validation Loss: 0.1341, Average Prediction Time (s): 0.000090 per graph
#
# No improvement in validation loss for 27 epoch(s).
#
# Epoch 97/2000, Training Loss: 0.1038, Validation Loss: 0.1335, Average Prediction Time (s): 0.000091 per graph
#
# No improvement in validation loss for 28 epoch(s).
#
# Epoch 98/2000, Training Loss: 0.1041, Validation Loss: 0.1334, Average Prediction Time (s): 0.000091 per graph
#
# No improvement in validation loss for 29 epoch(s).
#
# Epoch 99/2000, Training Loss: 0.1040, Validation Loss: 0.1339, Average Prediction Time (s): 0.000179 per graph
#
# No improvement in validation loss for 30 epoch(s).
#
# Epoch 100/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000084 per graph
#
# No improvement in validation loss for 31 epoch(s).
#
# Epoch 101/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000094 per graph
#
# No improvement in validation loss for 32 epoch(s).
#
# Epoch 102/2000, Training Loss: 0.1038, Validation Loss: 0.1340, Average Prediction Time (s): 0.000107 per graph
#
# No improvement in validation loss for 33 epoch(s).
#
# Epoch 103/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000100 per graph
#
# No improvement in validation loss for 34 epoch(s).
#
# Epoch 104/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000127 per graph
#
# No improvement in validation loss for 35 epoch(s).
#
# Epoch 105/2000, Training Loss: 0.1038, Validation Loss: 0.1334, Average Prediction Time (s): 0.000106 per graph
#
# No improvement in validation loss for 36 epoch(s).
#
# Epoch 106/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000128 per graph
#
# No improvement in validation loss for 37 epoch(s).
#
# Epoch 107/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000106 per graph
#
# No improvement in validation loss for 38 epoch(s).
#
# Epoch 108/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000130 per graph
#
# No improvement in validation loss for 39 epoch(s).
#
# Epoch 109/2000, Training Loss: 0.1036, Validation Loss: 0.1342, Average Prediction Time (s): 0.000108 per graph
#
# No improvement in validation loss for 40 epoch(s).
#
# Epoch 110/2000, Training Loss: 0.1038, Validation Loss: 0.1338, Average Prediction Time (s): 0.000096 per graph
#
# No improvement in validation loss for 41 epoch(s).
#
# Epoch 111/2000, Training Loss: 0.1040, Validation Loss: 0.1336, Average Prediction Time (s): 0.000106 per graph
#
# No improvement in validation loss for 42 epoch(s).
#
# Epoch 112/2000, Training Loss: 0.1043, Validation Loss: 0.1343, Average Prediction Time (s): 0.000120 per graph
#
# No improvement in validation loss for 43 epoch(s).
#
# Epoch 113/2000, Training Loss: 0.1038, Validation Loss: 0.1336, Average Prediction Time (s): 0.000105 per graph
#
# No improvement in validation loss for 44 epoch(s).
#
# Epoch 114/2000, Training Loss: 0.1039, Validation Loss: 0.1337, Average Prediction Time (s): 0.000120 per graph
#
# No improvement in validation loss for 45 epoch(s).
#
# Epoch 115/2000, Training Loss: 0.1042, Validation Loss: 0.1334, Average Prediction Time (s): 0.000148 per graph
#
# No improvement in validation loss for 46 epoch(s).
#
# Epoch 116/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000118 per graph
#
# No improvement in validation loss for 47 epoch(s).
#
# Epoch 117/2000, Training Loss: 0.1034, Validation Loss: 0.1345, Average Prediction Time (s): 0.000115 per graph
#
# No improvement in validation loss for 48 epoch(s).
#
# Epoch 118/2000, Training Loss: 0.1041, Validation Loss: 0.1351, Average Prediction Time (s): 0.000105 per graph
#
# No improvement in validation loss for 49 epoch(s).
#
# Epoch 119/2000, Training Loss: 0.1039, Validation Loss: 0.1340, Average Prediction Time (s): 0.000115 per graph
#
# No improvement in validation loss for 50 epoch(s).
#
# Epoch 120/2000, Training Loss: 0.1039, Validation Loss: 0.1336, Average Prediction Time (s): 0.000106 per graph
#
# No improvement in validation loss for 51 epoch(s).
#
# Epoch 121/2000, Training Loss: 0.1036, Validation Loss: 0.1342, Average Prediction Time (s): 0.000108 per graph
#
# No improvement in validation loss for 52 epoch(s).
#
# Epoch 122/2000, Training Loss: 0.1037, Validation Loss: 0.1343, Average Prediction Time (s): 0.000105 per graph
#
# No improvement in validation loss for 53 epoch(s).
#
# Epoch 123/2000, Training Loss: 0.1036, Validation Loss: 0.1336, Average Prediction Time (s): 0.000102 per graph
#
# No improvement in validation loss for 54 epoch(s).
#
# Epoch 124/2000, Training Loss: 0.1038, Validation Loss: 0.1337, Average Prediction Time (s): 0.000117 per graph
#
# No improvement in validation loss for 55 epoch(s).
#
# Epoch 125/2000, Training Loss: 0.1035, Validation Loss: 0.1336, Average Prediction Time (s): 0.000112 per graph
#
# No improvement in validation loss for 56 epoch(s).
#
# Epoch 126/2000, Training Loss: 0.1036, Validation Loss: 0.1335, Average Prediction Time (s): 0.000111 per graph
#
# No improvement in validation loss for 57 epoch(s).
#
# Epoch 127/2000, Training Loss: 0.1039, Validation Loss: 0.1336, Average Prediction Time (s): 0.000111 per graph
#
# No improvement in validation loss for 58 epoch(s).
#
# Epoch 128/2000, Training Loss: 0.1039, Validation Loss: 0.1347, Average Prediction Time (s): 0.000099 per graph
#
# No improvement in validation loss for 59 epoch(s).
#
# Epoch 129/2000, Training Loss: 0.1038, Validation Loss: 0.1345, Average Prediction Time (s): 0.000098 per graph
#
# No improvement in validation loss for 60 epoch(s).
#
# Epoch 130/2000, Training Loss: 0.1038, Validation Loss: 0.1337, Average Prediction Time (s): 0.000076 per graph
#
# No improvement in validation loss for 61 epoch(s).
#
# Epoch 131/2000, Training Loss: 0.1039, Validation Loss: 0.1335, Average Prediction Time (s): 0.000072 per graph
#
# No improvement in validation loss for 62 epoch(s).
#
# Epoch 132/2000, Training Loss: 0.1036, Validation Loss: 0.1339, Average Prediction Time (s): 0.000098 per graph
#
# No improvement in validation loss for 63 epoch(s).
#
# Epoch 133/2000, Training Loss: 0.1037, Validation Loss: 0.1341, Average Prediction Time (s): 0.000075 per graph
#
# No improvement in validation loss for 64 epoch(s).
#
# Epoch 134/2000, Training Loss: 0.1036, Validation Loss: 0.1341, Average Prediction Time (s): 0.000077 per graph
#
# No improvement in validation loss for 65 epoch(s).
#
# Epoch 135/2000, Training Loss: 0.1036, Validation Loss: 0.1336, Average Prediction Time (s): 0.000074 per graph
#
# No improvement in validation loss for 66 epoch(s).
#
# Epoch 136/2000, Training Loss: 0.1038, Validation Loss: 0.1335, Average Prediction Time (s): 0.000073 per graph
#
# No improvement in validation loss for 67 epoch(s).
#
# Epoch 137/2000, Training Loss: 0.1036, Validation Loss: 0.1336, Average Prediction Time (s): 0.000080 per graph
#
# No improvement in validation loss for 68 epoch(s).
#
# Epoch 138/2000, Training Loss: 0.1036, Validation Loss: 0.1345, Average Prediction Time (s): 0.000074 per graph
#
# No improvement in validation loss for 69 epoch(s).
#
# Epoch 139/2000, Training Loss: 0.1040, Validation Loss: 0.1349, Average Prediction Time (s): 0.000072 per graph
#
# No improvement in validation loss for 70 epoch(s).
#
# Epoch 140/2000, Training Loss: 0.1037, Validation Loss: 0.1341, Average Prediction Time (s): 0.000085 per graph
#
# No improvement in validation loss for 71 epoch(s).
#
# Epoch 141/2000, Training Loss: 0.1033, Validation Loss: 0.1334, Average Prediction Time (s): 0.000072 per graph
#
# No improvement in validation loss for 72 epoch(s).
#
# Epoch 142/2000, Training Loss: 0.1040, Validation Loss: 0.1335, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 73 epoch(s).
#
# Epoch 143/2000, Training Loss: 0.1038, Validation Loss: 0.1335, Average Prediction Time (s): 0.000068 per graph
#
# No improvement in validation loss for 74 epoch(s).
#
# Epoch 144/2000, Training Loss: 0.1040, Validation Loss: 0.1347, Average Prediction Time (s): 0.000085 per graph
#
# No improvement in validation loss for 75 epoch(s).
#
# Epoch 145/2000, Training Loss: 0.1038, Validation Loss: 0.1342, Average Prediction Time (s): 0.000067 per graph
#
# No improvement in validation loss for 76 epoch(s).
#
# Epoch 146/2000, Training Loss: 0.1038, Validation Loss: 0.1335, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 77 epoch(s).
#
# Epoch 147/2000, Training Loss: 0.1037, Validation Loss: 0.1335, Average Prediction Time (s): 0.000098 per graph
#
# No improvement in validation loss for 78 epoch(s).
#
# Epoch 148/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000069 per graph
#
# No improvement in validation loss for 79 epoch(s).
#
# Epoch 149/2000, Training Loss: 0.1037, Validation Loss: 0.1341, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 80 epoch(s).
#
# Epoch 150/2000, Training Loss: 0.1041, Validation Loss: 0.1337, Average Prediction Time (s): 0.000075 per graph
#
# No improvement in validation loss for 81 epoch(s).
#
# Epoch 151/2000, Training Loss: 0.1040, Validation Loss: 0.1342, Average Prediction Time (s): 0.000071 per graph
#
# No improvement in validation loss for 82 epoch(s).
#
# Epoch 152/2000, Training Loss: 0.1038, Validation Loss: 0.1343, Average Prediction Time (s): 0.000072 per graph
#
# No improvement in validation loss for 83 epoch(s).
#
# Epoch 153/2000, Training Loss: 0.1037, Validation Loss: 0.1340, Average Prediction Time (s): 0.000068 per graph
#
# No improvement in validation loss for 84 epoch(s).
#
# Epoch 154/2000, Training Loss: 0.1036, Validation Loss: 0.1337, Average Prediction Time (s): 0.000071 per graph
#
# No improvement in validation loss for 85 epoch(s).
#
# Epoch 155/2000, Training Loss: 0.1039, Validation Loss: 0.1335, Average Prediction Time (s): 0.000075 per graph
#
# No improvement in validation loss for 86 epoch(s).
#
# Epoch 156/2000, Training Loss: 0.1037, Validation Loss: 0.1339, Average Prediction Time (s): 0.000070 per graph
#
# No improvement in validation loss for 87 epoch(s).
#
# Epoch 157/2000, Training Loss: 0.1036, Validation Loss: 0.1341, Average Prediction Time (s): 0.000072 per graph
#
# No improvement in validation loss for 88 epoch(s).
#
# Epoch 158/2000, Training Loss: 0.1036, Validation Loss: 0.1339, Average Prediction Time (s): 0.000101 per graph
#
# No improvement in validation loss for 89 epoch(s).
#
# Epoch 159/2000, Training Loss: 0.1037, Validation Loss: 0.1343, Average Prediction Time (s): 0.000073 per graph
#
# No improvement in validation loss for 90 epoch(s).
#
# Epoch 160/2000, Training Loss: 0.1036, Validation Loss: 0.1339, Average Prediction Time (s): 0.000112 per graph
#
# No improvement in validation loss for 91 epoch(s).
#
# Epoch 161/2000, Training Loss: 0.1040, Validation Loss: 0.1335, Average Prediction Time (s): 0.000078 per graph
#
# No improvement in validation loss for 92 epoch(s).
#
# Epoch 162/2000, Training Loss: 0.1036, Validation Loss: 0.1341, Average Prediction Time (s): 0.000067 per graph
#
# No improvement in validation loss for 93 epoch(s).
#
# Epoch 163/2000, Training Loss: 0.1037, Validation Loss: 0.1345, Average Prediction Time (s): 0.000083 per graph
#
# No improvement in validation loss for 94 epoch(s).
#
# Epoch 164/2000, Training Loss: 0.1039, Validation Loss: 0.1338, Average Prediction Time (s): 0.000071 per graph
#
# No improvement in validation loss for 95 epoch(s).
#
# Epoch 165/2000, Training Loss: 0.1035, Validation Loss: 0.1338, Average Prediction Time (s): 0.000066 per graph
#
# No improvement in validation loss for 96 epoch(s).
#
# Epoch 166/2000, Training Loss: 0.1036, Validation Loss: 0.1338, Average Prediction Time (s): 0.000086 per graph
#
# No improvement in validation loss for 97 epoch(s).
#
# Epoch 167/2000, Training Loss: 0.1036, Validation Loss: 0.1334, Average Prediction Time (s): 0.000073 per graph
#
# No improvement in validation loss for 98 epoch(s).
#
# Epoch 168/2000, Training Loss: 0.1041, Validation Loss: 0.1334, Average Prediction Time (s): 0.000132 per graph
#
# No improvement in validation loss for 99 epoch(s).
#
# Epoch 169/2000, Training Loss: 0.1037, Validation Loss: 0.1336, Average Prediction Time (s): 0.000090 per graph
#
# No improvement in validation loss for 100 epoch(s).
#
# Early stopping triggered after 100 epochs without improvement.
# Loaded the best model from checkpoint.
# <ipython-input-125-6678b9b5f8d4>:80: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path))

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Evaluate on test data
model.eval()
predictions = []
true_values = []

with torch.no_grad():
    for data in test_loader:
        out = model(data).squeeze()  # Predictions from the model
        predictions.append(out.cpu().numpy())  # Append predictions
        true_values.append(data.y.cpu().numpy())  # Append true values

# Flatten the lists
predictions = [item for sublist in predictions for item in sublist]
true_values = [item for sublist in true_values for item in sublist]



# Calculate Mean Squared Error
mse = mean_squared_error(true_values, predictions)
r2 = r2_score(true_values, predictions)

print(f'Mean Squared Error on Test Set: {mse:.4f}')
print(f'R^2 Score on Test Set: {r2:.9f}')

# Scatter Plot for Predictions vs True Values
plt.figure(figsize=(8, 6))
plt.scatter(true_values, predictions, alpha=0.6, edgecolor='k', label='Predictions')
plt.plot([min(true_values), max(true_values)], [min(true_values), max(true_values)],
         'r--', lw=2, label='Ideal Fit (y=x)')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Predictions vs True Values on Test Set')
plt.legend()
plt.grid()
plt.show()
# Out:
# Mean Squared Error on Test Set: 0.1334
# R^2 Score on Test Set: 0.000093216

# %%
for i in range(len(predictions)):
  print(f'prediction: {predictions[i]}, true: {true_values[i]}')
# Out:
# prediction: 0.26521211862564087, true: 0.1317525953054428
# prediction: 0.2651640772819519, true: 1.0
# prediction: 0.2653054893016815, true: 0.1317525953054428
# prediction: 0.2648153305053711, true: 0.1317525953054428
# prediction: 0.2648153305053711, true: 0.006893291603773832
# prediction: 0.2655954658985138, true: 0.996871292591095
# prediction: 0.26461729407310486, true: 0.006893291603773832
# prediction: 0.26615580916404724, true: 0.1317525953054428
# prediction: 0.2659947872161865, true: 0.006893291603773832
# prediction: 0.2653054893016815, true: 0.1317525953054428
# prediction: 0.2651640772819519, true: 1.0
# prediction: 0.26524338126182556, true: 0.003525075037032366
# prediction: 0.26538482308387756, true: 0.003525075037032366
# prediction: 0.26594942808151245, true: 0.006893291603773832
# prediction: 0.2648438811302185, true: 0.1317525953054428
# prediction: 0.2656451463699341, true: 0.006893291603773832
# prediction: 0.2655501365661621, true: 0.006893291603773832
# prediction: 0.265502005815506, true: 0.006893291603773832
# prediction: 0.26521211862564087, true: 0.1317525953054428
# prediction: 0.2658078074455261, true: 0.1317525953054428
# prediction: 0.26594942808151245, true: 0.1317525953054428
# prediction: 0.2651640772819519, true: 1.0
# prediction: 0.26569053530693054, true: 0.7798449397087097
# prediction: 0.2654390037059784, true: 0.006893291603773832
# prediction: 0.2660500109195709, true: 0.1317525953054428
# prediction: 0.26609817147254944, true: 0.1317525953054428
# prediction: 0.26609107851982117, true: 0.006893291603773832
# prediction: 0.2651049792766571, true: 0.006893291603773832
# prediction: 0.26461726427078247, true: 0.1317525953054428
# prediction: 0.2653864324092865, true: 0.0
# prediction: 0.26513350009918213, true: 0.1317525953054428
# prediction: 0.26578396558761597, true: 0.003525075037032366
# prediction: 0.2655971050262451, true: 0.779221773147583
# prediction: 0.26483166217803955, true: 0.003525075037032366
# prediction: 0.2658078074455261, true: 0.006893291603773832
# prediction: 0.2656165659427643, true: 0.996871292591095
# prediction: 0.26533836126327515, true: 0.6861389875411987
# prediction: 0.2657005488872528, true: 0.1317525953054428
# prediction: 0.2648153305053711, true: 0.1317525953054428
# prediction: 0.2648153305053711, true: 0.1317525953054428
# prediction: 0.26601412892341614, true: 1.0
# prediction: 0.2659975588321686, true: 0.1317525953054428
# prediction: 0.2654585540294647, true: 0.996871292591095
# prediction: 0.2655610144138336, true: 0.1317525953054428
